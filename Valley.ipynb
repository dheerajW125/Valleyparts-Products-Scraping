# %%
fetch("https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/connect/communities/0DBRj000000080nOAA/navigation-menu/navigation-menu-items?addHomeMenuItem=false&navigationLinkSetDeveloperName=Global_Navigation&publishStatus=Live&language=en-US&asGuest=false&htmlEncode=false", {
  "headers": {
    "accept": "*/*",
    "accept-language": "en-US,en-IN;q=0.9,en-GB;q=0.8,en;q=0.7",
    "content-type": "application/json;charset=UTF-8",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "cec48ccb46fe72b6",
    "x-b3-traceid": "cec48ccb46fe72b6",
    "x-sfdc-request-id": "17383504632454fa9f"
  },
  "referrer": "https://valleyparts.valmont.com/category/products/0ZGRj00000002rROAQ",
  "referrerPolicy": "origin-when-cross-origin",
  "body": null,
  "method": "GET",
  "mode": "cors",
  "credentials": "include"
});

# %%
fetch("https://valleyparts.valmont.com/webruntime/api/apex/execute?language=en-US&asGuest=false&htmlEncode=false", {
  "headers": {
    "accept": "*/*",
    "accept-language": "en-US,en-IN;q=0.9,en-GB;q=0.8,en;q=0.7",
    "content-type": "application/json; charset=utf-8",
    "csrf-token": "..pzbYJ-VcCrEcMil9S6mj9UsrnOa9IJZJpp4FzNvDThs=",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "8d37c671b516e907",
    "x-b3-traceid": "5bc96b19316c02ad",
    "x-sfdc-request-id": "1738351967347c0914"
  },
  "referrer": "https://valleyparts.valmont.com/category/products/0ZGRj00000002rROAQ",
  "referrerPolicy": "origin-when-cross-origin",
  "body": "{\"namespace\":\"\",\"classname\":\"@udd/01pRj000000hRWy\",\"method\":\"productSearch\",\"isContinuation\":false,\"params\":{\"communityId\":\"0DBRj000000080nOAA\",\"accountId\":\"0015000000ICHYV\",\"searchQuery\":{\"categoryId\":\"0ZGRj00000002rROAQ\",\"searchTerm\":\"\",\"refinements\":[],\"page\":2,\"fields\":[\"Name\",\"Part_Short_Description__c\"]}},\"cacheable\":false}",
  "method": "POST",
  "mode": "cors",
  "credentials": "include"
});

# %%
fetch("https://valleyparts.valmont.com/webruntime/api/apex/execute?language=en-US&asGuest=false&htmlEncode=false", {
  "headers": {
    "accept": "*/*",
    "accept-language": "en-US,en-IN;q=0.9,en-GB;q=0.8,en;q=0.7",
    "content-type": "application/json; charset=utf-8",
    "csrf-token": "..pzbYJ-VcCrEcMil9S6mj9UsrnOa9IJZJpp4FzNvDThs=",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "f09f9c73c54e5bba",
    "x-b3-traceid": "5ab4e8be65f14fe0",
    "x-sfdc-request-id": "17383519411805ec55"
  },
  "referrer": "https://valleyparts.valmont.com/category/products/0ZGRj00000002rROAQ",
  "referrerPolicy": "origin-when-cross-origin",
  "body": "{\"namespace\":\"\",\"classname\":\"@udd/01pRj000000hRWy\",\"method\":\"productSearch\",\"isContinuation\":false,\"params\":{\"communityId\":\"0DBRj000000080nOAA\",\"accountId\":\"0015000000ICHYV\",\"searchQuery\":{\"categoryId\":\"0ZGRj00000002rROAQ\",\"searchTerm\":\"\",\"refinements\":[],\"page\":1,\"fields\":[\"Name\",\"Part_Short_Description__c\"]}},\"cacheable\":false}",
  "method": "POST",
  "mode": "cors",
  "credentials": "include"
});

# %%
fetch("https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/search/products?categoryId=0ZGRj00000002rROAQ&page=0&includeQuantityRule=false&language=en-US&asGuest=false&htmlEncode=false", {
  "headers": {
    "accept": "*/*",
    "accept-language": "en-US,en-IN;q=0.9,en-GB;q=0.8,en;q=0.7",
    "content-type": "application/json;charset=UTF-8",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "fb80fdac3fb801bf",
    "x-b3-traceid": "663d9d7b2b3cb764",
    "x-sfdc-request-id": "1738385649428f02dd"
  },
  "referrer": "https://valleyparts.valmont.com/category/products/0ZGRj00000002rROAQ",
  "referrerPolicy": "origin-when-cross-origin",
  "body": null,
  "method": "GET",
  "mode": "cors",
  "credentials": "include"
});

# %%
import requests

url = "https://valleyparts.valmont.com/webruntime/api/apex/execute?language=en-US&asGuest=false&htmlEncode=false"

# Headers (Keep all necessary headers)
headers = {
    "accept": "*/*",
    "content-type": "application/json; charset=utf-8",
    "csrf-token": "..cdVg8fpHGMrYQlKKfSqUoTiK5NiQGf3HMdyX1QlS1tg="
}

# Cookies from your session
cookies = {
    "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
    "sid_Client": "j000008HVjA00000007XAC",
    "oid": "00D500000007XAC",
    "clientSrc": "203.192.241.95",
    "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
    "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
}

# API request payload
data = {
    "namespace": "",
    "classname": "@udd/01pRj000000hRWy",
    "method": "productSearch",
    "isContinuation": False,
    "params": {
        "communityId": "0DBRj000000080nOAA",
        "accountId": "0015000000ICHYV",
        "searchQuery": {
            "categoryId": "0ZGRj00000002rROAQ",
            "searchTerm": "",
            "refinements": [],
            "page": 250,
            "fields": ["Name", "Part_Short_Description__c"]
        }
    },
    "cacheable": False
}

# Make the request with headers and cookies
response = requests.post(url, headers=headers, cookies=cookies, json=data)

# Print the response
print("Status Code:", response.status_code)
try:
    print("Response JSON:", response.json())  # If response is JSON
    with open('Product_category.json', 'w') as f:
      json.dump(response.json(), f, indent=4)
except:
    print("Response Text:", response.text)  # If not JSON
# Out:
# Status Code: 200
# ...

# %%
import requests
import json
url = "https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/search/products"
params = {
    "categoryId": "0ZGRj00000002tAOAQ",# taek category id from above
    "page": 249,
    "includeQuantityRule": "false",
    "language": "en-US",
    "asGuest": "false",
    "htmlEncode": "false"
}

# Headers (Keep necessary headers)
headers = {
    "accept": "*/*",
    "content-type": "application/json;charset=UTF-8",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "0657d114b287d35f",
    "x-b3-traceid": "13b01137f3b8b9a3",
    "x-sfdc-request-id": "1738387342040da171"
}

# Cookies from your session
cookies = {
    "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
    "sid_Client": "j000008HVjA00000007XAC",
    "oid": "00D500000007XAC",
    "clientSrc": "203.192.241.95",
    "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
    "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
}

# Make the GET request with headers and cookies
response = requests.get(url, headers=headers, cookies=cookies, params=params)

# Print the response
print("Status Code:", response.status_code)
try:
    print("Response JSON:", response.json())  # If response is JSON
    with open('Product_id_error.json', 'w') as f:
      json.dump(response.json(), f, indent=4)

except:
    print("Response Text:", response.text)  # If not JSON
# Out:
# Status Code: 200
# ...

# %%
import requests

url = "https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/connect/communities/0DBRj000000080nOAA/seo/properties/01tRj000007JG3RIAW"

params = {
    "language": "en-US",
    "asGuest": "false",
    "htmlEncode": "false"
}

# Headers (Include necessary headers)
headers = {
    "accept": "*/*",
    "content-type": "application/json;charset=UTF-8",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "5ab72d41c3e88c03",
    "x-b3-traceid": "5ab72d41c3e88c03",
    "x-sfdc-request-id": "173838797198925a44"
}

# Cookies from your session
cookies = {
    "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
    "sid_Client": "j000008HVjA00000007XAC",
    "oid": "00D500000007XAC",
    "clientSrc": "203.192.241.95",
    "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
    "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
}

# Make the GET request with headers and cookies
response = requests.get(url, headers=headers, cookies=cookies, params=params)

# Print the response
print("Status Code:", response.status_code)
try:
    print("Response JSON:", response.json())  # If response is JSON
    with open('Basic_name_details.json', 'w') as f:
      json.dump(response.json(), f, indent=4)
except:
    print("Response Text:", response.text)  # If not JSON
# Out:
# Status Code: 200
# Response JSON: {'canonicalUrl': 'https://valleyparts.valmont.com/product/truss-angle-trapezoid-plate/01tRj000007JG3RIAW', 'complexFields': {}, 'fields': {'Name': 'Truss Angle Trapezoid Plate'}, 'hrefLangUrls': {'en_US': 'https://valleyparts.valmont.com/product/truss-angle-trapezoid-plate/01tRj000007JG3RIAW', 'es': 'https://valleyparts.valmont.com/es/product/truss-angle-trapezoid-plate/01tRj000007JG3RIAW'}, 'isSeoIndexed': True, 'objectName': 'Product', 'recordId': '01tRj000007JG3RIAW', 'recordName': 'Truss Angle Trapezoid Plate'}

# %%
import requests

url = "https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/products/01tRj000007JG3RIAW"

params = {
    "language": "en-US",
    "asGuest": "false",
    "htmlEncode": "false"
}

# Headers (Keep necessary headers)
headers = {
    "accept": "*/*",
    "content-type": "application/json;charset=UTF-8",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "21e61b950af1e38c",
    "x-b3-traceid": "21e61b950af1e38c",
    "x-sfdc-request-id": "1738387976445dbd45"
}

# Cookies from your session
cookies = {
    "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
    "sid_Client": "j000008HVjA00000007XAC",
    "oid": "00D500000007XAC",
    "clientSrc": "203.192.241.95",
    "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
    "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
}

# Make the GET request with headers and cookies
response = requests.get(url, headers=headers, cookies=cookies, params=params)

# Print the response
print("Status Code:", response.status_code)
try:
    print("Response JSON:", response.json())  # If response is JSON
    with open('Deep_product_details.json', 'w') as f:
      json.dump(response.json(), f, indent=4)
except:
    print("Response Text:", response.text)  # If not JSON
# Out:
# Status Code: 200
# ...

# %%
import requests

url = "https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/pricing/products/01tRj000007JG3RIAW"

params = {
    "allProductSellingModelPrices": "true",
    "language": "en-US",
    "asGuest": "false",
    "htmlEncode": "false"
}

# Headers (Include necessary headers)
headers = {
    "accept": "*/*",
    "content-type": "application/json;charset=UTF-8",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-b3-sampled": "0",
    "x-b3-spanid": "b429356f53726257",
    "x-b3-traceid": "b429356f53726257",
    "x-sfdc-request-id": "1738387976445d74c8"
}

# Cookies from your session
cookies = {
    "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
    "sid_Client": "j000008HVjA00000007XAC",
    "oid": "00D500000007XAC",
    "clientSrc": "203.192.241.95",
    "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
    "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
}

# Make the GET request with headers and cookies
response = requests.get(url, headers=headers, cookies=cookies, params=params)

# Print the response
print("Status Code:", response.status_code)
try:
    print("Response JSON:", response.json())  # If response is JSON
    with open('Deep_product_details_2.json', 'w') as f:
      json.dump(response.json(), f, indent=4)
except:
    print("Response Text:", response.text)  # If not JSON
# Out:
# Status Code: 200
# Response JSON: {'currencyIsoCode': 'USD', 'listPrice': '31.78', 'lowestUnitPrice': None, 'priceAdjustment': None, 'pricebookEntryId': None, 'productPriceEntries': [{'error': {}, 'listPrice': '31.78', 'lowestUnitPrice': None, 'priceAdjustment': None, 'pricebookEntryId': None, 'productSellingModelId': None, 'success': True, 'unitPrice': '17.06'}], 'productSellingModelId': None, 'unitPrice': '17.06'}

# %% [markdown]
# Sample For Test

# %%
import requests
import json
import csv

# Function to fetch product categories
def fetch_categories():
    url = "https://valleyparts.valmont.com/webruntime/api/apex/execute?language=en-US&asGuest=false&htmlEncode=false"
    headers = {
        "accept": "*/*",
        "content-type": "application/json; charset=utf-8",
        "csrf-token": "..cdVg8fpHGMrYQlKKfSqUoTiK5NiQGf3HMdyX1QlS1tg="
    }
    cookies = {
        "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
        "sid_Client": "j000008HVjA00000007XAC",
        "oid": "00D500000007XAC",
        "clientSrc": "203.192.241.95",
        "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
        "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
    }
    data = {
        "namespace": "",
        "classname": "@udd/01pRj000000hRWy",
        "method": "productSearch",
        "isContinuation": False,
        "params": {
            "communityId": "0DBRj000000080nOAA",
            "accountId": "0015000000ICHYV",
            "searchQuery": {
                "categoryId": "0ZGRj00000002rROAQ",
                "searchTerm": "",
                "refinements": [],
                "page": 1,
                "fields": ["Name", "Part_Short_Description__c"]
            }
        },
        "cacheable": False
    }
    response = requests.post(url, headers=headers, cookies=cookies, json=data)
    if response.status_code == 200:
        return response.json()['returnValue']['categories']
    else:
        print("Failed to fetch categories")
        return []

# Function to fetch products for a given category
def fetch_products(category_id):
    url = "https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/search/products"
    params = {
        "categoryId": category_id,
        "page": 0,  # Start with page 0
        "includeQuantityRule": "false",
        "language": "en-US",
        "asGuest": "false",
        "htmlEncode": "false"
    }
    headers = {
        "accept": "*/*",
        "content-type": "application/json;charset=UTF-8",
        "priority": "u=1, i",
        "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-b3-sampled": "0",
        "x-b3-spanid": "0657d114b287d35f",
        "x-b3-traceid": "13b01137f3b8b9a3",
        "x-sfdc-request-id": "1738387342040da171"
    }
    cookies = {
        "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
        "sid_Client": "j000008HVjA00000007XAC",
        "oid": "00D500000007XAC",
        "clientSrc": "203.192.241.95",
        "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
        "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
    }
    products = []
    while True:
        response = requests.get(url, headers=headers, cookies=cookies, params=params)
        if response.status_code == 200:
            data = response.json()
            # Check if 'productsPage' key exists in the response
            if 'productsPage' in data and 'products' in data['productsPage']:
                # Add products to the list
                products.extend(data['productsPage']['products'])
                # If the number of products is less than 20, we've reached the last page
                if len(data['productsPage']['products']) < 20:
                    break
                # Increment the page number for the next request
                params['page'] += 1
            else:
                # If 'productsPage' key is not found, break the loop
                break
        else:
            # If the request fails, print an error and break the loop
            print(f"Failed to fetch products for category {category_id}")
            break
    return products

# Function to fetch product details from the correct endpoint
def fetch_product_details(product_id):
    url = f"https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/products/{product_id}"
    params = {
        "language": "en-US",
        "asGuest": "false",
        "htmlEncode": "false"
    }
    headers = {
        "accept": "*/*",
        "content-type": "application/json;charset=UTF-8",
        "priority": "u=1, i",
        "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-b3-sampled": "0",
        "x-b3-spanid": "21e61b950af1e38c",
        "x-b3-traceid": "21e61b950af1e38c",
        "x-sfdc-request-id": "1738387976445dbd45"
    }
    cookies = {
        "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
        "sid_Client": "j000008HVjA00000007XAC",
        "oid": "00D500000007XAC",
        "clientSrc": "203.192.241.95",
        "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
        "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
    }
    response = requests.get(url, headers=headers, cookies=cookies, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch details for product {product_id}")
        return None

# Function to fetch product SEO details (name and canonical URL)
def fetch_product_seo_details(product_id):
    url = f"https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/connect/communities/0DBRj000000080nOAA/seo/properties/{product_id}"
    params = {
        "language": "en-US",
        "asGuest": "false",
        "htmlEncode": "false"
    }
    headers = {
        "accept": "*/*",
        "content-type": "application/json;charset=UTF-8",
        "priority": "u=1, i",
        "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-b3-sampled": "0",
        "x-b3-spanid": "5ab72d41c3e88c03",
        "x-b3-traceid": "5ab72d41c3e88c03",
        "x-sfdc-request-id": "173838797198925a44"
    }
    cookies = {
        "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
        "sid_Client": "j000008HVjA00000007XAC",
        "oid": "00D500000007XAC",
        "clientSrc": "203.192.241.95",
        "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
        "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
    }
    response = requests.get(url, headers=headers, cookies=cookies, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch SEO details for product {product_id}")
        return None

# Function to fetch product pricing
def fetch_product_pricing(product_id):
    url = f"https://valleyparts.valmont.com/webruntime/api/services/data/v62.0/commerce/webstores/0ZERj0000002PC1OAM/pricing/products/{product_id}"
    params = {
        "allProductSellingModelPrices": "true",
        "language": "en-US",
        "asGuest": "false",
        "htmlEncode": "false"
    }
    headers = {
        "accept": "*/*",
        "content-type": "application/json;charset=UTF-8",
        "priority": "u=1, i",
        "sec-ch-ua": "\"Not A(Brand\";v=\"8\", \"Chromium\";v=\"132\", \"Google Chrome\";v=\"132\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-b3-sampled": "0",
        "x-b3-spanid": "b429356f53726257",
        "x-b3-traceid": "b429356f53726257",
        "x-sfdc-request-id": "1738387976445d74c8"
    }
    cookies = {
        "sid": "00D500000007XAC!AQEAQDglsFai.7LTdOJCras0aPF9cP0XOuXrxnD63GyXcjyH5MCJU5fL3M655rYJ_oqo_p0lyU8Jtc27OqKu.94HVUyzllRF",
        "sid_Client": "j000008HVjA00000007XAC",
        "oid": "00D500000007XAC",
        "clientSrc": "203.192.241.95",
        "guest_uuid_essential_0DMRj00000009Ec": "365df736-3795-45d7-b697-340345ff5dce",
        "cqcid": "c7668eb2-c004-457f-adfb-9325834ff33a"
    }
    response = requests.get(url, headers=headers, cookies=cookies, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch pricing for product {product_id}")
        return None

# Main function to create CSV
def create_csv():
    categories = fetch_categories()
    # Limit the number of categories to process for testing
    categories = categories[:2]  # Process only the first 2 categories
    print("categories ", categories)
    with open('products.csv', 'w', newline='') as csvfile:
        fieldnames = ['Category URL', 'Category Name', 'Product URL', 'SKU','SKU Alternative', 'Product Name', 'Product Image', 'Weight Shipping', 'Weight UOM', 'Clustered Specs', 'List Price', 'Unit Price', 'Currency']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for category in categories:
            category_url = f"https://valleyparts.valmont.com/category/products/{category['categoryId']}"
            category_name = category['categoryName']
            products = fetch_products(category['categoryId'])
            # Limit the number of products to process for testing
            products = products[:5]  # Process only the first 5 products
            for product in products:
                product_id = product['id']
                sku = product['fields']['ProductCode']['value']
                # Fetch SEO details (product name and canonical URL)
                seo_details = fetch_product_seo_details(product_id)
                if seo_details:
                    product_name = seo_details['fields']['Name']
                    product_url = seo_details['canonicalUrl']
                else:
                    product_name = ''
                    product_url = ''
                # Fetch product details (weight, image, etc.)
                product_details = fetch_product_details(product_id)
                print("product_details :", product_details)
                    # Extract fields for product-specific details
                # product_details = product_details.get('fields', {})
                if product_details:
                    product_image = f"https://res.cloudinary.com/valleyagprod/image/upload/if_md:!background_removal!_eq_!true!/e_background_removal/if_end/b_auto,c_pad,dpr_1.0,f_auto,h_500,q_auto,w_500/{product_details.get('Main_Part_Image__c', '')}?pgw=1" if product_details.get('Main_Part_Image__c') else ''
                    # Weight shipping is in fields, but the actual field names may differ. You might need to access the fields properly
                    weight_shipping = product_details.get('fields', {}).get('Weight_Shipping__c', '')  # Adjust field names as per actual data
                    weight_uom = product_details.get('fields', {}).get('Weight_UOM__c', '')  # Adjust field names as per actual data
                    # Accessing the SKU from the 'fields' dictionary
                    SKU_alternative = product_details.get('fields', {}).get('StockKeepingUnit', '')  # Using .get() to safely access the key



                    # Clustered specs are fields with '_c' suffix, so you can gather them
                    clustered_specs = {k.replace('_', ' '): v for k, v in product_details['fields'].items() if k.endswith('_c') and v is not None}

                else:
                    product_image = ''
                    weight_shipping = ''
                    weight_uom = ''
                    clustered_specs = {}
                    SKU_alternative = ''
                # Fetch pricing details
                pricing = fetch_product_pricing(product_id)
                list_price = pricing.get('listPrice', '') if pricing else ''
                unit_price = pricing.get('unitPrice', '') if pricing else ''
                currency = pricing.get('currencyIsoCode', '') if pricing else ''
                # Write row to CSV
                writer.writerow({
                    'Category URL': category_url,
                    'Category Name': category_name,
                    'Product URL': product_url,
                    'SKU': sku,
                    'SKU Alternative': SKU_alternative,
                    'Product Name': product_name,
                    'Product Image': product_image,
                    'Weight Shipping': weight_shipping,
                    'Weight UOM': weight_uom,
                    'Clustered Specs': clustered_specs,
                    'List Price': list_price,
                    'Unit Price': unit_price,
                    'Currency': currency

                })

if __name__ == "__main__":
    create_csv()
# Out:
# categories  [{'categoryId': '0ZGRj00000002tGOAQ', 'categoryName': 'Structural', 'productCount': 2065}, {'categoryId': '0ZGRj00000002tFOAQ', 'categoryName': 'Sprinklers', 'productCount': 1503}]
# ...
